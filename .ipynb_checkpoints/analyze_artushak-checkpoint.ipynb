# %%
import pandas
import numpy
import matplotlib as plt

data_filename = 'data.csv'

def load_structure(course_id):
    return pandas.read_csv('../data_stepic/course-' + str(course_id) + '-structure.csv')

def load_events(course_id):
    return pandas.read_csv('../data_stepic/course-' + str(course_id) + '-events.csv')

#course_ids = [7, 63, 65, 75, 91]
course_ids = [7, 63]
num_courses = len(course_ids)
course_structures = []
course_lessons = []
course_events = []

for course_id in course_ids:
    structure = load_structure(course_id)
    events = load_events(course_id)
    course_structures += [structure]
    course_lessons += [structure.lesson_id.unique()]
    course_events += [events]

#DEBUG
course_structures[0]
course_events[0]
#END

for i in range(num_courses):
    print('COURSE  : ' + str(course_ids[i]))
    print('LESSONS : ' + str(course_lessons[i]))

lesson_matches = []

for i_a in range(num_courses):
    for lesson_i_a in course_lessons[i_a]:
        for i_b in range(num_courses):
            if i_a == i_b:
                continue
            for lesson_i_a in course_lessons[i_b]:
                lesson_events_a = []
                for course_a_event_idx, course_a_event in course_events[i_a].iterrows():
                    #column 2 is step_id
                    if course_a_event['step_id'] in course_structures[i_a].step_id[course_structures[i_a].lesson_id == lesson_i_a]:
                        continue
                    lesson_events_a += [course_a_event]
                print(course_lessons[i_a])
                print(course_lessons[i_b])
                print(lesson_events_a)
# Out:
#      course_id  module_id  module_position  lesson_id  lesson_position  \
# 0            7         17                1        531                2
# 1            7         17                1        531                2
# 2            7         17                1        531                2
# 3            7         17                1        531                2
# 4            7         17                1        531                2
# 5            7         17                1        531                2
# 6            7         17                1        531                2
# 7            7         17                1        531                2
# 8            7         17                1        531                2
# 9            7         17                1        531                2
# 10           7         17                1        532                3
# 11           7         17                1        532                3
# 12           7         17                1        532                3
# 13           7         17                1        532                3
# 14           7         17                1        532                3
# 15           7         17                1        532                3
# 16           7         17                1        532                3
# 17           7         17                1        532                3
# 18           7         17                1        532                3
# 19           7         17                1        532                3
# 20           7         17                1        533                4
# 21           7         17                1        533                4
# 22           7         17                1        533                4
# 23           7         17                1        533                4
# 24           7         17                1        533                4
# 25           7         17                1        533                4
# 26           7         17                1        534                5
# 27           7         17                1        534                5
# 28           7         17                1        534                5
# 29           7         17                1        534                5
# ..         ...        ...              ...        ...              ...
# 324          7        131                6        563                1
# 325          7        131                6        564                2
# 326          7        131                6        564                2
# 327          7        131                6        564                2
# 328          7        131                6        564                2
# 329          7        131                6        564                2
# 330          7        131                6        564                2
# 331          7        131                6        564                2
# 332          7        131                6        564                2
# 333          7        131                6        564                2
# 334          7        131                6        564                2
# 335          7        131                6        564                2
# 336          7        131                6        566                3
# 337          7        131                6        566                3
# 338          7        131                6        566                3
# 339          7        131                6        566                3
# 340          7        131                6        566                3
# 341          7        131                6        566                3
# 342          7        131                6        566                3
# 343          7        131                6        567                4
# 344          7        131                6        567                4
# 345          7        131                6        567                4
# 346          7        131                6        567                4
# 347          7        131                6        567                4
# 348          7        131                6        567                4
# 349          7        131                6        567                4
# 350          7        131                6        567                4
# 351          7       1309                7      24498                1
# 352          7       1309                7      24498                1
# 353          7       1309                7      24498                1
#
#      step_id  step_position step_type  step_cost
# 0       2824              9    choice          1
# 1       2825             10    choice          1
# 2       2828              1      text          0
# 3       4848              2     video          0
# 4       4850              3     video          0
# 5       4851              4     video          0
# 6       6219              5     video          0
# 7       6220              6     video          0
# 8       6221              7     video          0
# 9       6222              8     video          0
# 10      2827              3      text          0
# 11      2829             10    choice          1
# 12      6950              2     video          0
# 13      6951              4     video          0
# 14      6954              5     video          0
# 15      6956              6     video          0
# 16      6957              7     video          0
# 17      6958              8     video          0
# 18      6959              9     video          0
# 19      7257              1      text          0
# 20      6962              2     video          0
# 21      6963              3     video          0
# 22      6964              4     video          0
# 23      6965              5     video          0
# 24      7268              1      text          0
# 25     44097              6    choice          1
# 26      2832              9      text          0
# 27      2839              8      text          0
# 28      4287             10    choice          1
# 29      6969              3     video          0
# ..       ...            ...       ...        ...
# 324    11575              8      code          2
# 325     2708              1      text          0
# 326    11463              9      code          2
# 327    11469              6      text          0
# 328    11471              8      code          2
# 329    11479              5      code          2
# 330    11540              2     video          0
# 331    11541              3     video          0
# 332    11542              4     video          0
# 333    11543             10     video          0
# 334    11572             11      code          3
# 335    11685              7      text          0
# 336     2710              1      text          0
# 337    11484              7      code          2
# 338    11486              6      text          0
# 339    11544              3     video          0
# 340    11545              2     video          0
# 341    11546              4     video          0
# 342    11547              5     video          0
# 343     2711              1      text          0
# 344    11487              3      code          2
# 345    11548              2     video          0
# 346    11549              4     video          0
# 347    11550              5     video          0
# 348    11551              6     video          0
# 349    11552              7     video          0
# 350    11553              8     video          0
# 351    84377              3      text          0
# 352    84530              1      text          0
# 353    84531              2     video          0
#
# [354 rows x 9 columns]
#          user_id           action  step_id        time
# 0              1           viewed    10192  1465182971
# 1              1           viewed    39540  1465182918
# 2              2           passed    11064  1465182853
# 3              2       discovered    11064  1465182853
# 4              2           viewed    11064  1465182853
# 5              1           viewed    11077  1465182700
# 6              1           viewed    44097  1465182653
# 7              3  started_attempt    11164  1465182319
# 8              1           viewed    39540  1465182117
# 9              4           passed     7322  1465182052
# 10             4       discovered     7322  1465182052
# 11             4           viewed     7322  1465182052
# 12             4           passed    41483  1465181906
# 13             4       discovered    41483  1465181906
# 14             4           viewed    41483  1465181906
# 15             4           passed    43608  1465181698
# 16             4       discovered    43608  1465181698
# 17             4           viewed    43608  1465181698
# 18             1           viewed     2701  1465181677
# 19             1           viewed     9769  1465181539
# 20             1           viewed    11061  1465181472
# 21             1           viewed     7052  1465181371
# 22             4           passed     7311  1465181327
# 23             4       discovered     7311  1465181327
# 24             4           viewed     7311  1465181327
# 25             1           viewed    11455  1465181219
# 26             1           viewed    40959  1465181183
# 27             4           passed     7312  1465181069
# 28             4       discovered     7312  1465181069
# 29             4           viewed     7312  1465181069
# ...          ...              ...      ...         ...
# 5577275     5920           passed     2694  1403166054
# 5577276     5920       discovered     2694  1403166054
# 5577277     5920           viewed     2694  1403166054
# 5577278     5920           passed     2693  1403166048
# 5577279     5920       discovered     2693  1403166048
# 5577280     5920           viewed     2693  1403166048
# 5577281     5920           passed     2692  1403166040
# 5577282     5920       discovered     2692  1403166040
# 5577283     5920           viewed     2692  1403166040
# 5577284     5920           passed     2691  1403166028
# 5577285     5920       discovered     2691  1403166028
# 5577286     5920           viewed     2691  1403166028
# 5577287     5920           passed     2690  1403166018
# 5577288     5920       discovered     2690  1403166018
# 5577289     5920           viewed     2690  1403166018
# 5577290     5920           passed     2689  1403166013
# 5577291     5920       discovered     2689  1403166013
# 5577292     5920           viewed     2689  1403166013
# 5577293     5920           passed     2688  1403166007
# 5577294     5920       discovered     2688  1403166007
# 5577295     5920           viewed     2688  1403166007
# 5577296     5920           passed     2687  1403165994
# 5577297     5920       discovered     2687  1403165994
# 5577298     5920           viewed     2687  1403165994
# 5577299     5920           passed     2682  1403165946
# 5577300     5920       discovered     2682  1403165946
# 5577301     5920           viewed     2682  1403165946
# 5577302     5920           passed     2681  1403165936
# 5577303     5920       discovered     2681  1403165936
# 5577304     5920           viewed     2681  1403165936
#
# [5577305 rows x 4 columns]
